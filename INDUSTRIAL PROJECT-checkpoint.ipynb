# %% [markdown]
# # IMPORTING THE REQUIRED LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # IMPORTING THE DATASET

# %%
data = pd.read_csv(r'C:\Users\More\Downloads\1614238459_salarydata.csv')

# %% [markdown]
# # EXPLORINGTHE DATASET

# %%
data
# Out:
#        age         workclass   education  education-num      marital-status  \
# 0       39         State-gov   Bachelors             13       Never-married
# 1       50  Self-emp-not-inc   Bachelors             13  Married-civ-spouse
# 2       38           Private     HS-grad              9            Divorced
# 3       53           Private        11th              7  Married-civ-spouse
# 4       28           Private   Bachelors             13  Married-civ-spouse
# ...    ...               ...         ...            ...                 ...
# 32556   27           Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private     HS-grad              9  Married-civ-spouse
# 32558   58           Private     HS-grad              9             Widowed
# 32559   22           Private     HS-grad              9       Never-married
# 32560   52      Self-emp-inc     HS-grad              9  Married-civ-spouse
#
# ...

# %%
data.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# ...

# %%
data.tail()
# Out:
#        age     workclass   education  education-num      marital-status  \
# 32556   27       Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40       Private     HS-grad              9  Married-civ-spouse
# 32558   58       Private     HS-grad              9             Widowed
# 32559   22       Private     HS-grad              9       Never-married
# 32560   52  Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32556             0              38  United-States  <=50K
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %% [markdown]
# # CHECKING THE MISSING VALUES

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
h = data[data['age']=='?']
h
# Out:
# C:\Users\More\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['workclass']=='?']
h
# Out:
#        age workclass     education  education-num         marital-status  \
# 27      54         ?  Some-college             10     Married-civ-spouse
# 61      32         ?       7th-8th              4  Married-spouse-absent
# 69      25         ?  Some-college             10          Never-married
# 77      67         ?          10th              6     Married-civ-spouse
# 106     17         ?          10th              6          Never-married
# ...    ...       ...           ...            ...                    ...
# 32530   35         ?     Bachelors             13     Married-civ-spouse
# 32531   30         ?     Bachelors             13          Never-married
# 32539   71         ?     Doctorate             16     Married-civ-spouse
# 32541   41         ?       HS-grad              9              Separated
# 32542   72         ?       HS-grad              9     Married-civ-spouse
#
#       occupation   relationship                race     sex  capital-gain  \
# ...

# %%
h = data[data['education']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['education-num']=='?']
h
# Out:
# C:\Users\More\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['marital-status']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['occupation']=='?']
h
# Out:
#        age workclass     education  education-num         marital-status  \
# 27      54         ?  Some-college             10     Married-civ-spouse
# 61      32         ?       7th-8th              4  Married-spouse-absent
# 69      25         ?  Some-college             10          Never-married
# 77      67         ?          10th              6     Married-civ-spouse
# 106     17         ?          10th              6          Never-married
# ...    ...       ...           ...            ...                    ...
# 32530   35         ?     Bachelors             13     Married-civ-spouse
# 32531   30         ?     Bachelors             13          Never-married
# 32539   71         ?     Doctorate             16     Married-civ-spouse
# 32541   41         ?       HS-grad              9              Separated
# 32542   72         ?       HS-grad              9     Married-civ-spouse
#
#       occupation   relationship                race     sex  capital-gain  \
# ...

# %%
h = data[data['relationship']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['sex']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['capital-gain']=='?']
h
# Out:
# C:\Users\More\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['capital-loss']=='?']
h
# Out:
# C:\Users\More\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['hours-per-week']=='?']
h
# Out:
# C:\Users\More\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
data['native-country'].loc[data['native-country']=='?']
# Out:
# 14       ?
# 38       ?
# 51       ?
# 61       ?
# 93       ?
#         ..
# 32449    ?
# 32469    ?
# 32492    ?
# 32510    ?
# 32525    ?
# Name: native-country, Length: 583, dtype: object

# %%
h = data[data['salary']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
h = data[data['race']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
data['education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
sns.pairplot(data)

# %%
corrmatrix = data.corr()
plt.subplots(figsize =(20,8))
sns.heatmap(corrmatrix, vmin =-.4,vmax=0.9,annot =True ,linewidth =.2)

# %%
data['relationship'].mode()
# Out:
# 0    Husband
# dtype: object

# %%
h1 = data[data['native-country'] != "?"]
f1 = h1.mode()
data['native-country'] = data['native-country'].replace("?",data['native-country'].mode())

# %%
h = data[data['native-country']=='?']
h
# Out:
#        age         workclass     education  education-num  \
# 14      40           Private     Assoc-voc             11
# 38      31           Private  Some-college             10
# 51      18           Private       HS-grad              9
# 61      32                 ?       7th-8th              4
# 93      30           Private       HS-grad              9
# ...    ...               ...           ...            ...
# 32449   44      Self-emp-inc       Masters             14
# 32469   58      Self-emp-inc     Doctorate             16
# 32492   42  Self-emp-not-inc       HS-grad              9
# 32510   39           Private       HS-grad              9
# 32525   81                 ?     Assoc-voc             11
#
#               marital-status      occupation   relationship  \
# 14        Married-civ-spouse    Craft-repair        Husband
# 38        Married-civ-spouse           Sales        Husband
# 51             Never-married   Other-service      Own-child
# ...

# %% [markdown]
# # CLEANING THE DATA SET (REPLACING THE "?")

# %%
data['native-country'].mode()
# Out:
# 0    United-States
# dtype: object

# %%
data['native-country'] = data['native-country'].replace('?','United-States')

# %%
h = data[data['native-country']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
data['occupation'].mode()
# Out:
# 0    Prof-specialty
# dtype: object

# %%
data['occupation'] = data['occupation'].replace('?','Prof-specialty')

# %%
h = data[data['occupation']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
data['workclass'].mode()
# Out:
# 0    Private
# dtype: object

# %%
data['workclass'] = data['workclass'].replace('?','Private')

# %%
h = data[data['workclass']=='?']
h
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# # FINDING OUTLIERS

# %% [markdown]
# # AGE

# %%
plt.boxplot(data['age'])
plt.title('box plot of age')
# Out:
# Text(0.5, 1.0, 'box plot of age')

# %%
Q1 = np.percentile(data['age'],25,interpolation = 'midpoint')
Q2 =np.percentile(data['age'],50,interpolation = 'midpoint')
Q3 = np.percentile(data['age'],75,interpolation = 'midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 28.0
# 37.0
# 48.0

# %%
IQR = Q3-Q1
low_limit = Q1-1.5*IQR
up_limit = Q3+1.5*IQR

# %%
print(up_limit)
print(low_limit)
# Out:
# 78.0
# -2.0

# %%
Outliers = []
for x in data['age']:
    if((x>up_limit) or (x<low_limit)):
        Outliers.append(x)

# %%
Outliers
# Out:
# [79,
#  90,
#  80,
#  81,
#  90,
#  88,
#  90,
#  90,
#  80,
#  90,
#  81,
#  82,
#  79,
#  81,
#  80,
#  83,
#  90,
#  90,
#  79,
#  81,
#  90,
#  90,
#  80,
#  90,
#  90,
#  79,
#  79,
#  84,
#  90,
#  80,
#  90,
#  81,
#  83,
#  84,
#  81,
#  79,
#  85,
#  82,
#  79,
#  80,
#  90,
#  90,
#  90,
#  84,
#  80,
#  90,
#  90,
#  79,
#  84,
#  90,
#  79,
#  90,
#  90,
#  90,
#  82,
#  81,
#  90,
#  84,
#  79,
#  81,
#  82,
#  81,
#  80,
#  90,
#  80,
#  84,
#  82,
#  79,
#  90,
#  84,
#  90,
#  83,
#  79,
#  81,
#  80,
#  79,
#  80,
#  79,
#  80,
#  90,
#  90,
#  80,
#  90,
#  90,
#  81,
#  83,
#  82,
#  90,
#  90,
#  81,
#  80,
#  80,
#  90,
#  79,
#  80,
#  82,
#  85,
#  80,
#  79,
#  90,
#  81,
#  79,
#  80,
#  79,
#  81,
#  82,
#  88,
#  90,
#  82,
#  88,
#  84,
#  83,
#  79,
#  86,
#  90,
#  90,
#  82,
#  83,
#  81,
#  79,
#  90,
#  80,
#  81,
#  79,
#  84,
#  84,
#  79,
#  90,
#  80,
#  81,
#  81,
#  81,
#  90,
#  87,
#  90,
#  80,
#  80,
#  82,
#  90,
#  90,
#  85,
#  82,
# ...

# %%
ind1 = data['age']>up_limit
f =data.loc[ind1].index

# %%
'data.drop(f,inplace = True)'
# Out:
# 'data.drop(f,inplace = True)'

# %%
plt.boxplot(data['age'])
plt.title('box plot of age')
# Out:
# Text(0.5, 1.0, 'box plot of age')

# %% [markdown]
# ## education-num

# %%
plt.boxplot(data['education-num'])
plt.title('box plot of education-num')
# Out:
# Text(0.5, 1.0, 'box plot of education-num')

# %%
Q1 = np.percentile(data['education-num'],25,interpolation = 'midpoint')
Q2 =np.percentile(data['education-num'],50,interpolation = 'midpoint')
Q3 = np.percentile(data['education-num'],75,interpolation = 'midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 9.0
# 10.0
# 12.0

# %%
IQR = Q3-Q1
low_limit = Q1-1.5*IQR
up_limit = Q3+1.5*IQR

# %%
print(up_limit)
print(low_limit)
# Out:
# 16.5
# 4.5

# %%
Outliers = []
for x in data['education-num']:
    if((x>up_limit) or (x<low_limit)):
        Outliers.append(x)

# %%
Outliers
# Out:
# [4,
#  3,
#  4,
#  4,
#  2,
#  4,
#  3,
#  4,
#  2,
#  1,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  2,
#  1,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  4,
#  1,
#  4,
#  1,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  1,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  1,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
# ...

# %%
ind1 = data['education-num']<low_limit
data.loc[ind1].index
# Out:
# Int64Index([   15,    56,    61,    79,   160,   183,   195,   214,   221,
#               224,
#             ...
#             32401, 32403, 32413, 32425, 32430, 32431, 32432, 32448, 32479,
#             32517],
#            dtype='int64', length=1198)

# %%
data = data.drop(columns="education-num")

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %% [markdown]
# ## capital-gain

# %%
plt.boxplot(data['capital-gain'])
plt.title('box plot of capital-gain')
# Out:
# Text(0.5, 1.0, 'box plot of capital-gain')

# %%
Q1 = np.percentile(data['capital-gain'],25,interpolation = 'midpoint')
Q2 =np.percentile(data['capital-gain'],50,interpolation = 'midpoint')
Q3 = np.percentile(data['capital-gain'],75,interpolation = 'midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 0.0

# %%
IQR = Q3-Q1
low_limit = Q1-1.5*IQR
up_limit = Q3+1.5*IQR

# %%
print(up_limit)
print(low_limit)
# Out:
# 0.0
# 0.0

# %%
Outliers = []
for x in data['capital-gain']:
    if((x>up_limit) or (x<low_limit)):
        Outliers.append(x)

# %%
Outliers
# Out:
# [2174,
#  14084,
#  5178,
#  5013,
#  2407,
#  14344,
#  15024,
#  7688,
#  34095,
#  4064,
#  4386,
#  14084,
#  7298,
#  7298,
#  15024,
#  1409,
#  3674,
#  4064,
#  1055,
#  2407,
#  7298,
#  7298,
#  5178,
#  15024,
#  3464,
#  7688,
#  4386,
#  7298,
#  2050,
#  7298,
#  7298,
#  7688,
#  15024,
#  2176,
#  2174,
#  594,
#  594,
#  15024,
#  15024,
#  7688,
#  20051,
#  5013,
#  7688,
#  2174,
#  6849,
#  1055,
#  15024,
#  15024,
#  15024,
#  5178,
#  4101,
#  1111,
#  8614,
#  3411,
#  2597,
#  25236,
#  4386,
#  4650,
#  7298,
#  9386,
#  2407,
#  594,
#  14084,
#  7688,
#  7688,
#  1055,
#  2463,
#  5178,
#  3103,
#  4386,
#  4386,
#  10605,
#  2174,
#  7688,
#  15024,
#  3103,
#  4101,
#  2964,
#  3325,
#  2580,
#  15024,
#  15024,
#  3103,
#  1409,
#  7688,
#  7298,
#  3471,
#  7298,
#  3103,
#  4865,
#  15024,
#  7298,
#  3411,
#  10605,
#  4386,
#  5178,
#  15024,
#  7688,
#  4650,
#  99999,
#  15024,
#  6514,
#  5178,
#  15024,
#  7298,
#  1471,
#  3674,
#  2329,
# ...

# %%
ind1 = data['capital-gain']>up_limit
data.loc[ind1].index
# Out:
# Int64Index([    0,     8,     9,    59,    60,    84,   101,   105,   106,
#               113,
#             ...
#             32399, 32434, 32462, 32466, 32473, 32515, 32518, 32538, 32548,
#             32560],
#            dtype='int64', length=2712)

# %%
data = data.drop(columns="capital-gain")

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %% [markdown]
# ## capital-loss

# %%
plt.boxplot(data['capital-loss'])
plt.title('box plot of capital-loss')
# Out:
# Text(0.5, 1.0, 'box plot of capital-loss')

# %%
Q1 = np.percentile(data['capital-loss'],25,interpolation = 'midpoint')
Q2 =np.percentile(data['capital-loss'],50,interpolation = 'midpoint')
Q3 = np.percentile(data['capital-loss'],75,interpolation = 'midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 0.0

# %%
IQR = Q3-Q1
low_limit = Q1-1.5*IQR
up_limit = Q3+1.5*IQR

# %%
print(up_limit)
print(low_limit)
# Out:
# 0.0
# 0.0

# %%
Outliers = []
for x in data['capital-loss']:
    if((x>up_limit) or (x<low_limit)):
        Outliers.append(x)

# %%
Outliers
# Out:
# [2042,
#  1408,
#  1902,
#  1573,
#  1902,
#  1887,
#  1719,
#  1762,
#  1564,
#  2179,
#  1816,
#  1980,
#  1977,
#  1876,
#  1340,
#  2206,
#  1741,
#  1977,
#  1485,
#  1887,
#  1564,
#  2339,
#  2415,
#  2179,
#  1977,
#  1887,
#  1408,
#  1980,
#  1977,
#  1380,
#  1977,
#  1887,
#  1902,
#  1762,
#  1721,
#  1902,
#  1380,
#  2051,
#  2377,
#  1669,
#  2352,
#  1902,
#  1721,
#  1672,
#  653,
#  2415,
#  2415,
#  1977,
#  2392,
#  1504,
#  1902,
#  1719,
#  2001,
#  1902,
#  1902,
#  1977,
#  1902,
#  1902,
#  1590,
#  1977,
#  1651,
#  2415,
#  1977,
#  1902,
#  1762,
#  1887,
#  1977,
#  1876,
#  1628,
#  1848,
#  1564,
#  1887,
#  1762,
#  1887,
#  1672,
#  1902,
#  2051,
#  2001,
#  1980,
#  1340,
#  2339,
#  1628,
#  1887,
#  1848,
#  1977,
#  1740,
#  2002,
#  1902,
#  1887,
#  1902,
#  1902,
#  1719,
#  2339,
#  1902,
#  1579,
#  1590,
#  1902,
#  1741,
#  1628,
#  2415,
#  1408,
#  1740,
#  2258,
#  1485,
#  1848,
#  1977,
#  1485,
#  1887,
#  1902,
#  1669,
#  1887,
# ...

# %%
ind1 = data['capital-loss']>up_limit
data.loc[ind1].index
# Out:
# Int64Index([   23,    32,    52,    93,    96,   112,   126,   131,   143,
#               148,
#             ...
#             32307, 32311, 32393, 32400, 32416, 32441, 32443, 32445, 32458,
#             32500],
#            dtype='int64', length=1519)

# %%
data = data.drop(columns="capital-loss")

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# ## hours-per-week

# %%
plt.boxplot(data['hours-per-week'])
plt.title('box plot of hours-per-week')
# Out:
# Text(0.5, 1.0, 'box plot of hours-per-week')

# %%
Q1 = np.percentile(data['hours-per-week'],25,interpolation = 'midpoint')
Q2 =np.percentile(data['hours-per-week'],50,interpolation = 'midpoint')
Q3 = np.percentile(data['hours-per-week'],75,interpolation = 'midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 40.0
# 40.0
# 45.0

# %%
IQR = Q3-Q1
low_limit = Q1-1.5*IQR
up_limit = Q3+1.5*IQR

# %%
print(up_limit)
print(low_limit)
# Out:
# 52.5
# 32.5

# %%
Outliers = []
for x in data['hours-per-week']:
    if((x>up_limit) or (x<low_limit)):
        Outliers.append(x)

# %%
Outliers
# Out:
# [13,
#  16,
#  80,
#  30,
#  60,
#  20,
#  60,
#  80,
#  15,
#  25,
#  30,
#  60,
#  55,
#  60,
#  58,
#  32,
#  70,
#  20,
#  2,
#  22,
#  30,
#  25,
#  60,
#  60,
#  32,
#  25,
#  56,
#  60,
#  28,
#  60,
#  60,
#  20,
#  30,
#  30,
#  24,
#  24,
#  2,
#  60,
#  20,
#  16,
#  20,
#  25,
#  12,
#  65,
#  1,
#  28,
#  24,
#  55,
#  60,
#  12,
#  60,
#  55,
#  20,
#  10,
#  20,
#  55,
#  70,
#  20,
#  20,
#  60,
#  30,
#  20,
#  30,
#  60,
#  12,
#  75,
#  24,
#  24,
#  98,
#  15,
#  60,
#  56,
#  16,
#  60,
#  80,
#  25,
#  54,
#  25,
#  15,
#  24,
#  10,
#  15,
#  55,
#  60,
#  30,
#  20,
#  8,
#  25,
#  25,
#  30,
#  24,
#  55,
#  15,
#  15,
#  10,
#  10,
#  30,
#  25,
#  6,
#  16,
#  55,
#  64,
#  65,
#  25,
#  24,
#  60,
#  19,
#  30,
#  18,
#  60,
#  72,
#  24,
#  25,
#  60,
#  28,
#  5,
#  55,
#  60,
#  20,
#  60,
#  16,
#  60,
#  24,
#  6,
#  30,
#  20,
#  20,
#  20,
#  60,
#  60,
#  25,
#  20,
#  20,
#  8,
#  30,
#  20,
#  24,
#  80,
#  58,
#  9,
#  30,
#  8,
#  20,
#  32,
# ...

# %%
ind1 = data['hours-per-week']>up_limit
data.loc[ind1].index
# Out:
# Int64Index([   10,    20,    27,    28,    52,    53,    54,    64,    72,
#                96,
#             ...
#             32495, 32500, 32506, 32520, 32523, 32530, 32531, 32532, 32536,
#             32548],
#            dtype='int64', length=3492)

# %%
data = data.drop(columns ='hours-per-week')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
data.describe(include ='object')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       24532     10501               14976            5983        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29753  24720

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   marital-status  32561 non-null  object
#  4   occupation      32561 non-null  object
#  5   relationship    32561 non-null  object
#  6   race            32561 non-null  object
#  7   sex             32561 non-null  object
#  8   native-country  32561 non-null  object
#  9   salary          32561 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %%
p= data['age'].value_counts()
p
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64

# %%
p = data['workclass'].value_counts()
p
# Out:
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
p = data['education'].value_counts()
p
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
p = data['marital-status'].value_counts()
p
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
p = data['occupation'].value_counts()
p
# Out:
# Prof-specialty       5983
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
p = data['relationship'].value_counts()
p
# Out:
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
p = data['race'].value_counts()
p
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
p = data['sex'].value_counts()
p
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
p = data['native-country'].value_counts()
p
# Out:
# United-States                 29753
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
p = data['salary'].value_counts()
p
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %% [markdown]
# ## CHECKING AGE ATTRIBUTE

# %%
freqgraph= data['age']
plt.xlabel('age')
plt.ylabel('count')
freqgraph.hist(figsize =(7,5))
plt.title(' AGE Distribution ')
plt.show()

# %% [markdown]
# ## CHECKING WORK CLASS

# %%
data['workclass'].value_counts().plot.pie(autopct ='%1.1f%%',shadow =True)
plt.title('WORK CLASS')
# Out:
# Text(0.5, 1.0, 'WORK CLASS')

# %% [markdown]
# ## Checking Education

# %%
graph = plt.subplots(figsize=(20,8))
sns.countplot('education',data=data,order=data['education'].value_counts().index)
plt.title("EDUCATION")
plt.grid()

# %% [markdown]
# ## Checking marital-status

# %%
data['marital-status'].value_counts().plot.pie(autopct ='%1.1f%%')
plt.title('marital-status')
# Out:
# Text(0.5, 1.0, 'marital-status')

# %% [markdown]
# ## Checking occupation

# %%
graph = plt.subplots(figsize=(18,6))
sns.countplot('occupation',data=data,order=data['occupation'].value_counts().index)
plt.grid()
plt.title('occupation')
# Out:
# Text(0.5, 1.0, 'occupation')

# %% [markdown]
# ## sex

# %%
data['sex'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('sex')
# Out:
# Text(0.5, 1.0, 'sex')

# %% [markdown]
# ## Relationship

# %%
data['relationship'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('relationship')
# Out:
# Text(0.5, 1.0, 'relationship')

# %% [markdown]
# ## Race

# %%
freqgraph= data['race']
plt.xlabel('race')
plt.ylabel('count')
freqgraph.hist(figsize =(7,5))
plt.title(' race Distribution ')
plt.show()

# %% [markdown]
# ## native-country

# %%
graph = plt.subplots(figsize=(30,4))
sns.countplot('native-country',data=data,order=data['native-country'].value_counts().index)
plt.grid()
plt.title('native-country')
data['native-country'].value_counts()
# Out:
# United-States                 29753
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %% [markdown]
# ## Salary

# %%
data['salary'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('salary')
# Out:
# Text(0.5, 1.0, 'salary')

# %% [markdown]
# ## LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
a=['workclass','education','marital-status','occupation','relationship','race','sex','native-country','salary']
for i in np.arange(len(a)):
    data[a[i]]=le.fit_transform(data[a[i]])

# %% [markdown]
# # train the data set

# %%
Y = data['salary']
X = data.drop(['salary'],axis =1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state =0)

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
Y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,f1_score,precision_score
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8078860090897924
# precision: 0.6266666666666667
# recall: 0.5216952573158425
# f1_score: 0.5693832599118943
# [[5543  616]
#  [ 948 1034]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Rand_ROC= roc_auc_score(Y_test,rf.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,rf.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="Random forest (area =%0.2f)" % Rand_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.savefig('Rand_ROC')
plt.show()

# %%
Y = data['salary']
X = data.drop(['salary','race','sex'],axis =1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state =0)
rf2 = RandomForestClassifier()
rf2.fit(X_train,Y_train)
Y_pred = rf2.predict(X_test)
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,f1_score,precision_score
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8086230192851002
# precision: 0.6289537712895377
# recall: 0.5216952573158425
# f1_score: 0.5703254274682845
# [[5549  610]
#  [ 948 1034]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Rand_ROC2= roc_auc_score(Y_test,rf2.predict(X_test))
fpr2,tpr2,threshold2 =roc_curve(Y_test,rf2.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,10))
plt.plot(fpr,tpr, label ="Random forest (area =%0.2f)" % Rand_ROC )
plt.plot(fpr2,tpr2, label ="Random forest2 (area =%0.2f)" % Rand_ROC2 )
plt.xlim([-0.05, 1.05])
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.legend(loc ="lower right")
plt.savefig('Rand_ROC')
plt.show()

# %%
Y = data['salary']
X = data.drop(['salary'],axis =1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state =0)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values = []
neighbors = np.arange(3,15)
for k in neighbors:
    Classifier = KNeighborsClassifier(n_neighbors = k,metric = 'minkowski')
    Classifier.fit(X_train,Y_train)
    Y_pred = Classifier.predict(X_test)
    acc = accuracy_score(Y_test,Y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.7911804446628178,
#  0.8018670924947795,
#  0.7996560619088564,
#  0.8024812676575359,
#  0.7995332268763051,
#  0.8027269377226385,
#  0.8028497727551898,
#  0.8014985873971257,
#  0.8010072472669205,
#  0.8040781230807026,
#  0.8027269377226385,
#  0.8028497727551898]

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('K value')
plt.ylabel('acc_value')
# Out:
# Text(0, 0.5, 'acc_value')

# %%
Classifier = KNeighborsClassifier(n_neighbors = 14,metric = 'minkowski')
Classifier.fit(X_train,Y_train)
Y_pred = Classifier.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8028497727551898
# precision: 0.6324666198172875
# recall: 0.45408678102926336
# f1_score: 0.5286343612334802
# [[5636  523]
#  [1082  900]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Classifier_ROC= roc_auc_score(Y_test,Classifier.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,Classifier.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="KNeighborsClassifier (area =%0.2f)" % Classifier_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # svm
# # (LINEAR SVM)

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel = 'linear')
svm_linear.fit(X_train,Y_train)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8028497727551898
# precision: 0.6324666198172875
# recall: 0.45408678102926336
# f1_score: 0.5286343612334802
# [[5636  523]
#  [1082  900]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
svm_linear_ROC= roc_auc_score(Y_test,svm_linear.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,svm_linear.predict_proba(X_test)[:,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-e0c8eaca87f5> in <module>
#       2 from sklearn.metrics import roc_curve
#       3 svm_linear_ROC= roc_auc_score(Y_test,svm_linear.predict(X_test))
# ----> 4 fpr,tpr,threshold =roc_curve(Y_test,svm_linear.predict_proba(X_test)[:,1])
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict_proba(self)
#     655         datasets.
#     656         """
# --> 657         self._check_proba()
#     658         return self._predict_proba
#     659
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _check_proba(self)
#     622     def _check_proba(self):
#     623         if not self.probability:
# --> 624             raise AttributeError("predict_proba is not available when "
#     625                                  " probability=False")
#     626         if self._impl not in ('c_svc', 'nu_svc'):
#
# ...

# %%
plt.figure()
plt.plot(fpr,tpr, label ="svm_linear (area =%0.2f)" % svm_linear_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # polynomial SVM

# %%
svm_polinomial = SVC(kernel = 'poly', degree = 3)
svm_polinomial.fit(X_train,Y_train)
Y_pred = svm_polinomial.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7565409654833558
# precision: 0.0
# recall: 0.0
# f1_score: 0.0
# [[6159    0]
#  [1982    0]]
# C:\Users\More\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
svm_polinomial_ROC= roc_auc_score(Y_test,svm_polinomial.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,svm_polinomial.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="svm_polinomial (area =%0.2f)" % svm_polinomial_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # RADIAL SVM

# %%
svm_radial = SVC(kernel = 'rbf')
svm_radial.fit(X_train,Y_train)
Y_pred = svm_radial.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7565409654833558
# precision: 0.0
# recall: 0.0
# f1_score: 0.0
# [[6159    0]
#  [1982    0]]
# C:\Users\More\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(X_train,Y_train)
Y_pred = logit_model.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7474511730745609
# precision: 0.37583892617449666
# recall: 0.056508577194752774
# f1_score: 0.09824561403508772
# [[5973  186]
#  [1870  112]]
# C:\Users\More\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_model_ROC= roc_auc_score(Y_test,logit_model.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,logit_model.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="logit_model (area =%0.2f)" % logit_model_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
Y_pred = dt.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7833190025795357
# precision: 0.5617913832199547
# recall: 0.5
# f1_score: 0.5290977042178323
# [[5386  773]
#  [ 991  991]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
dt_ROC= roc_auc_score(Y_test,dt.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,dt.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="dt (area =%0.2f)" % dt_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # GRADIENT BOOST CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train,Y_train)
Y_pred = gb.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8338042009581133
# precision: 0.6976744186046512
# recall: 0.5600403632694249
# f1_score: 0.6213266162888329
# [[5678  481]
#  [ 872 1110]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
gb_ROC= roc_auc_score(Y_test,gb.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,gb.predict_proba(X_test)[:,1])

# %%
plt.figure()
plt.plot(fpr,tpr, label ="gb (area =%0.2f)" % gb_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# # STANDARD SCALING

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
Y_pred = rf.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.809851369610613
# precision: 0.6288598574821853
# recall: 0.5343087790110999
# f1_score: 0.5777414075286416
# [[5534  625]
#  [ 923 1059]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Rand_ROC= roc_auc_score(Y_test,rf.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label ="Random forest (area =%0.2f)" % Rand_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.savefig('Rand_ROC')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values = []
neighbors = np.arange(3,15)
for k in neighbors:
    Classifier = KNeighborsClassifier(n_neighbors = k,metric = 'minkowski')
    Classifier.fit(X_train,Y_train)
    Y_pred = Classifier.predict(X_test)
    acc = accuracy_score(Y_test,Y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.7975678663554846,
#  0.805552143471318,
#  0.8057978135364205,
#  0.8082545141874462,
#  0.8080088441223436,
#  0.8077631740572411,
#  0.8080088441223436,
#  0.8088686893502027,
#  0.8105883798059207,
#  0.8118167301314335,
#  0.8132907505220489,
#  0.8130450804569463]

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('K value')
plt.ylabel('acc_value')
# Out:
# Text(0, 0.5, 'acc_value')

# %%
Classifier = KNeighborsClassifier(n_neighbors = 10,metric = 'minkowski')
Classifier.fit(X_train,Y_train)
Y_pred = Classifier.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8088686893502027
# precision: 0.646896551724138
# recall: 0.47325933400605447
# f1_score: 0.5466200466200466
# [[5647  512]
#  [1044  938]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Classifier_ROC= roc_auc_score(Y_test,Classifier.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,Classifier.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label ="KNeighborsClassifier (area =%0.2f)" % Classifier_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel = 'linear')
svm_linear.fit(X_train,Y_train)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8088686893502027
# precision: 0.646896551724138
# recall: 0.47325933400605447
# f1_score: 0.5466200466200466
# [[5647  512]
#  [1044  938]]

# %%
svm_polinomial = SVC(kernel = 'poly', degree = 3)
svm_polinomial.fit(X_train,Y_train)
Y_pred = svm_polinomial.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7577693158088686
# precision: 0.5806451612903226
# recall: 0.018163471241170535
# f1_score: 0.03522504892367906
# [[6133   26]
#  [1946   36]]

# %%
svm_radial = SVC(kernel = 'rbf')
svm_radial.fit(X_train,Y_train)
Y_pred = svm_radial.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7931458051836384
# precision: 0.5851428571428572
# recall: 0.5166498486377397
# f1_score: 0.5487674169346196
# [[5433  726]
#  [ 958 1024]]

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(X_train,Y_train)
Y_pred = logit_model.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.747942513204766
# precision: 0.43243243243243246
# recall: 0.11301715438950555
# f1_score: 0.1792
# [[5865  294]
#  [1758  224]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_model_ROC= roc_auc_score(Y_test,logit_model.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,logit_model.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label ="logit_model (area =%0.2f)" % logit_model_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
Y_pred = dt.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.7833190025795357
# precision: 0.5614430665163472
# recall: 0.5025227043390514
# f1_score: 0.5303514376996804
# [[5381  778]
#  [ 986  996]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
dt_ROC= roc_auc_score(Y_test,dt.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label ="dt (area =%0.2f)" % dt_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train,Y_train)
Y_pred = gb.predict(X_test)
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
# Out:
# accuracy: 0.8338042009581133
# precision: 0.6976744186046512
# recall: 0.5600403632694249
# f1_score: 0.6213266162888329
# [[5678  481]
#  [ 872 1110]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
gb_ROC= roc_auc_score(Y_test,gb.predict(X_test))
fpr,tpr,threshold =roc_curve(Y_test,gb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label ="gb (area =%0.2f)" % gb_ROC )
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-.05,1.05])
plt.show()

# %% [markdown]
# ## HYPERPARAMETER TUNNING

# %%
Y = data['salary']
X = data.drop(['salary'],axis =1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state =0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
parameters = {'learning_rate':[0.15,0.1,0.05,0.01,0.005,0.001], 'n_estimators':[100,250,500,750,1000,1250,1500,1750]}
Hypertuning = GridSearchCV(estimator =GradientBoostingClassifier( min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=10), 
            param_grid = parameters, scoring='accuracy',n_jobs=-1,iid=False, cv=10)
Hypertuning.fit(X_train,Y_train)
Hypertuning.best_params_, Hypertuning.best_score_
# Out:
# C:\Users\More\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# ({'learning_rate': 0.05, 'n_estimators': 1000}, 0.841031941031941)

# %%
parameter2 = {'max_depth':[2,3,4,5,6,7] }
Hypertuning = GridSearchCV(estimator =GradientBoostingClassifier(learning_rate=0.05,n_estimators=1000, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=10), 
            param_grid = parameter2, scoring='accuracy',n_jobs=4,iid=False, cv=5)
Hypertuning.fit(X_train,Y_train)
Hypertuning.best_params_, Hypertuning.best_score_
# Out:
# C:\Users\More\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# ({'max_depth': 3}, 0.8404995904995906)

# %%
gb = GradientBoostingClassifier(learning_rate=0.05, n_estimators=1000,max_depth=3, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=10)
gb.fit(X_train,Y_train)
Y_pred = gb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,f1_score,precision_score
print('accuracy:',accuracy_score(Y_test,Y_pred))
print('precision:',precision_score(Y_test,Y_pred))
print('recall:',recall_score(Y_test,Y_pred))
print("f1_score:",f1_score(Y_test,Y_pred))
# Out:
# accuracy: 0.8341727060557671
# precision: 0.6887694145758662
# recall: 0.5817356205852674
# f1_score: 0.6307439824945296
